# %% [markdown]
# # Matplotlib Library

# %% [markdown]
# Here We Disscuss about the matplotlib library

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x_axis = np.array([25,26,27])
y_axis = np.array([33,36,37])
plt.plot(x_axis,y_axis)
plt.show()

# %%
j_axis = np.array([21,22,23,24])
k_axis = np.array([31,32,33,34])
plt.plot(j_axis,k_axis,'o')
plt.show()

# %%
plt.plot(j_axis,k_axis,'red')
plt.show()

# %%
plt.plot(k_axis,'green')
plt.show()

# %%
l_axis = np.array([2,7,4,5,2,9])
plt.plot(l_axis,'blue')
plt.show()

# %% [markdown]
# # Markers

# %%
m_axis = np.array([2,5,7,4,8])
plt.plot(m_axis,marker = 'o')
plt.show()

# %%
plt.plot(m_axis,marker = '*')
plt.show()

# %%
plt.plot(m_axis,marker = '.')
plt.show()

# %%
plt.plot(m_axis,marker = 'x')
plt.show()

# %%
plt.plot(m_axis,marker = 'X')
plt.show()

# %%
plt.plot(m_axis,marker = '+')
plt.show()

# %%
plt.plot(m_axis,marker = 'P')
plt.show()

# %%
plt.plot(m_axis,marker = 's')
plt.show()

# %%
plt.plot(m_axis,marker = 'D')
plt.show()

# %%
plt.plot(m_axis,marker = 'p')
plt.show()

# %%
plt.plot(m_axis,marker = 'H')
plt.show()

# %%
plt.plot(m_axis,marker = 'v')
plt.show()

# %%
plt.plot(m_axis,marker = '>')
plt.show()

# %%
plt.plot(m_axis,marker = '<')
plt.show()

# %%
plt.plot(m_axis,marker = '1')
plt.show()

# %%
plt.plot(m_axis,marker = '_')
plt.show()

# %%
plt.plot(m_axis,'o:r')
plt.show()

# %%
plt.plot(m_axis,'+--g')
plt.show()

# %%
plt.plot(m_axis,'D-y')
plt.show()

# %%
plt.plot(m_axis,'D-.k')
plt.show()

# %%
plt.plot(m_axis,marker = 'o', ms = 30) # ms for increase the marker size
plt.show()

# %% [markdown]
# mec means markeredgecolour, set the colour at the the edge of marker

# %%
plt.plot(m_axis,marker = 'o', ms = 20, mec = 'g')
plt.show()

# %% [markdown]
# mfc means markerfacecolour-- set the colour inside the edge of the markers

# %%
plt.plot(m_axis,marker = 'o', ms = 20,mfc = 'y')
plt.show()

# %% [markdown]
# we can use both mec or mfc arguments to colour of the entire marker

# %%
plt.plot(m_axis,marker = 'o', ms = 20, mec = 'r', mfc = 'g')
plt.show()

# %% [markdown]
# You can also use Hexadecimal colour values

# %%
plt.plot(m_axis,marker = 'o', ms = 20, mec = '#4CAF50',mfc = '#4CAF50')
plt.show()

# %% [markdown]
# Mark each colour with the 'hotpink' colour

# %%
plt.plot(m_axis,marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %% [markdown]
# Linestyles

# %%
plt.plot(m_axis,linestyle = 'dotted')
plt.show()

# %%
plt.plot(m_axis,linestyle = 'dashed')
plt.show()

# %% [markdown]
# In short linestyle is also written as ls

# %%
plt.plot(m_axis,ls = '-.')
plt.show()

# %%
plt.plot(m_axis,ls = ':')
plt.show()

# %% [markdown]
# You can use colour as c

# %%
plt.plot(m_axis,color = 'r')
plt.show()

# %% [markdown]
# color = c in sort

# %%
plt.plot(m_axis,c = 'y')
plt.show()

# %%
plt.plot(m_axis,c = 'hotpink')
plt.show()

# %% [markdown]
# We can use the linewidth to change the linewidth of the line

# %% [markdown]
# linewidth = lw

# %% [markdown]
# the value is a floating number ,in points

# %%
plt.plot(m_axis,linewidth = '10.5')
plt.show()

# %%
plt.plot(m_axis,lw = '12.3')
plt.show()

# %% [markdown]
# You can plot as many lines as you like be simply adding more plt.plot() fun

# %%
g1 = np.array([3,2,5,6,7])
g2 = np.array([5,2,4,7,6])

plt.plot(g1)
plt.plot(g2)

plt.show()

# %%
f1 = np.array([3,2,4,5,9])
f2 = np.array([4,2,6,7,8])
f3 = np.array([3,4,6,1,8])
f4 = np.array([4,7,9,1,3])

plt.plot(f1)
plt.plot(f2)
plt.plot(f3)
plt.plot(f4)

plt.show()

# %%
f1 = np.array([3,2,4,5,9])
f2 = np.array([4,2,6,7,8])
f3 = np.array([3,4,6,1,8])
f4 = np.array([4,7,9,1,3])

plt.plot(f1,f2,f3,f4)
plt.show()

# %% [markdown]
# # Matplotlib Lables and Title

# %% [markdown]
# with pyplot you can use the xlable() and ylable() functions to set a lable
# for the x- axis and y-axis.

# %% [markdown]
# Add lable to the x-and y-axis

# %%
k = np.array([55,66,77,88,99,100])
k1 = np.array([32,33,34,35,38,36])

plt.plot(k,k1)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# Create a Title for a Plot

# %% [markdown]
# Use title() function to create it

# %%
k = np.array([55,66,77,88,99,100])
k1 = np.array([32,33,34,35,38,36])

plt.plot(k,k1)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Set font properties for Title and Lables

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'red','size':30}
font2 = {'family':'serif','color':'green','size':20}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# Note :- You can use the fontdict parameter in xlabel(),ylabel() and title() to set font properties for the title and labels.
#
# 'family':'serif' - is mandatary to use in font...

# %% [markdown]
# Position the Title

# %% [markdown]
# 1. You can use the loc parameter in title() to position the title.
# 2. Legal values are : 'left','right', and 'center' .
# 3. Default value is 'center'..

# %% [markdown]
# Position the title to the left:

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data",loc = 'left' )
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Matplotlib Adding Grid Lines

# %% [markdown]
# Add Grid Lines to a Plot

# %% [markdown]
# With Pyplot, you can use the grid() function to add grid lines to the plot...

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.grid()
plt.show()

# %% [markdown]
# Specify Which Grid Lines to Display

# %% [markdown]
# ..You can use the axis parameter in the grid() function to specify which grid lines to display...

# %% [markdown]
# Legal values are : 'x','y', and 'both'. Default value is 'both'..

# %% [markdown]
# ..Display only grid lines for the x-axis:

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(axis = 'x')

plt.plot(x, y)
plt.show()

# %% [markdown]
# ..Display only grid lines for the y-axis:

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(axis = 'y')

plt.plot(x, y)
plt.show()

# %% [markdown]
# Set Line Properties for the Grid

# %% [markdown]
# ..You can also set the line properties of the grid,like this:grid(color='color',linestyle = 'linestyle',linewidth = number)..

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.grid(color = 'green', linestyle = '-.', linewidth = 0.7)

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Matplotlib Subplot

# %% [markdown]
# 1. With the subplot() function you can draw multiple plots in one figure:

# %% [markdown]
# Draw 2 plots:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# # The subplot() Function

# %% [markdown]
# The subplot() function takes three arguments that describes the layout of the figure..
#
# The layout is organized in rows and columns which are represented by the first and second argument..
#
# The third arguments represents the index of the current plot..
#
#
# plt.subplot(1,2,1)
# ..the figure has 1 row,2 columns, and this plot is the first plot...
#
# plt.subplot(1,2,2)
# ..the figure has 1 row,2 columns, and this is the second plot...
#
#
# So, if we want a figure with 2 rows an 1 columns (meaning that the two plots will be displayed on top of each other instead of side-by-side), we can write the syntax like this:
#
#
# ..Draw 2 plots on top of each other:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ..You can draw as many plots you like on one figure, just describe the number of rows, columns, and the index of the plot...

# %% [markdown]
# >>Draw 6 plots:

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# # Title

# %% [markdown]
# ..You can add a title to each plot with the title() function:

# %% [markdown]
# ..2 plots, with titles:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# # Super Title

# %% [markdown]
# ..You can add a title to the entire figure with the suptitle() function:

# %% [markdown]
# .Add a title for the entire figure:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # Matplotlib Scatter

# %% [markdown]
# Creating Scatter Plots
#
# With Pyplot,you can use the scatter() function to draw a scatter plot..

# %% [markdown]
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %% [markdown]
# Example
# A simple scatter plot:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Draw two plots on the same figure:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# Note: The two plots are plotted with two different colors, by default blue and orange, you will learn how to change colors later in this chapter.

# %% [markdown]
# # Colours

# %% [markdown]
# You can set your own colour for each scatter plot with the color or the c argument:

# %% [markdown]
# Set your own color of the markers:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# Color Each Dot
#
#
# You can even set a specific color for each dot by using an array of colors as value for the c argument:
#
# Note: You cannot use the color argument for this, only the c argument.

# %% [markdown]
# Set your own color of the markers:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ColorMap
#
#
# The Matplotlib module has a number of available colormaps.
#
# A colormap is like a list of colors, where each color has a value that ranges from 0 to 100.
#
# Here is an example of a colormap:
#
#
#
# This colormap is called 'viridis' and as you can see it ranges from 0, which is a purple color, and up to 100, which is a yellow color.
#
# How to Use the ColorMap
#
# You can specify the colormap with the keyword argument cmap with the value of the colormap, in this case 'viridis' which is one of the built-in colormaps available in Matplotlib.
#
# In addition you have to create an array with values (from 0 to 100), one value for each of the point in the scatter plot:

# %% [markdown]
# Create a color array, and specify a colormap in the scatter plot:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %% [markdown]
# You can include the colormap in the drawing by including the plt.colorbar() statement:

# %% [markdown]
# Include the actual colormap:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# # Size

# %% [markdown]
# You can change the size of the dots with the s argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:
#
# Example

# %% [markdown]
# Set your own size for the markers:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# Alpha
#
#
# You can adjust the transparency of the dots with the alpha argument.
#
# Just like colors, make sure the array for sizes has the same length as the arrays for the x- and y-axis:
#
# Example
#
# Set your own size for the markers:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %% [markdown]
# # Combine Colour Size and Alpha

# %% [markdown]
# You can combine a colormap with different sizes on the dots. This is best visualized if the dots are transparent:
#
# Example
#
#
# Create random arrays with 100 values for x-points, y-points, colors and sizes:

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Matplotlib Bars

# %% [markdown]
# # Creating Bars

# %% [markdown]
# With Pyplot, you can use the bar() function to draw bar graphs:

# %% [markdown]
# Draw 4 bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# The bar() function takes arguments that describes the layout of the bars.
#
# The categories and their values represented by the first and second argument as arrays.

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # Horizontal Bars

# %% [markdown]
# If you want the bars to be displayed horizontally instead of vertically, use the barh() function:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %% [markdown]
# # Bar Color

# %% [markdown]
# The bar() and barh() takes the keyword argument color to set the color of the bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red")
plt.show()

# %% [markdown]
# Draw 4 "hot pink" bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %% [markdown]
# Draw 4 bars with a beautiful green color:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "#4CAF50") # for beautiful green color
plt.show()

# %% [markdown]
# # Bar Width

# %% [markdown]
# The bar() takes the keyword argument width to set the width of the bars:

# %% [markdown]
# Example
#
#
# Draw 4 very thin bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1)
plt.show()

# %% [markdown]
# The default width value is 0.8
#
#
# Note: For horizontal bars, use height instead of width.
#
#
#
# Bar Height
#
#
#
# The barh() takes the keyword argument height to set the height of the bars:
#
#
# Example
#
#
# Draw 4 very thin bars:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# The default height value is 0.8

# %% [markdown]
# # Matplotlib Histograms

# %% [markdown]
# # Histogram

# %% [markdown]
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.

# %% [markdown]
# # Create Histogram

# %% [markdown]
# In Matplotlib, we use the hist() function to create histograms.
#
# The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument.
#
# For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10..

# %% [markdown]
# Example
#
#
# A Normal Data Distribution by NumPy:

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [167.99580086 168.17879512 164.63756213 165.43129285 173.47523901
#  175.48008852 183.44257451 194.57418824 164.08948036 172.34769343
#  164.47679307 159.90368142 171.65061497 171.79849836 172.06063307
#  165.82847487 156.63895427 164.15260764 175.53179111 184.72720682
#  172.11762663 180.99741471 149.43902465 185.79498493 175.51629184
#  171.99520157 152.93435413 163.11532221 164.47168862 177.35179493
#  171.50122231 165.01761411 169.53906593 171.6883804  176.16431109
#  175.34283221 158.26051527 170.01803646 169.12809182 165.82523102
#  176.51001869 190.63101797 160.71612815 165.51686155 184.39204242
#  171.89040675 166.5366209  170.6792432  179.94664419 173.9114668
#  165.73608685 159.9004925  188.66465767 169.58650215 172.44127753
#  169.54695865 186.73700205 170.69600307 177.57952067 172.74968605
#  170.70597437 160.68225705 164.54612317 178.09259799 164.20703758
#  153.75199478 145.96237182 169.81467405 167.2557788  186.0554928
# ...

# %% [markdown]
# The hist() function will read the array and produce a histogram:

# %% [markdown]
# Example
#
#
# A simple histogram:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# # Matplotlib Pie Charts

# %% [markdown]
# # Creating Pie Charts

# %% [markdown]
# With Pyplot, you can use the pie() function to draw pie charts:

# %% [markdown]
# Example
#
# A simple pie chart:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# As you can see the pie chart draws one piece (called a wedge) for each value in the array (in this case [35, 25, 25, 15]).
#
#
#
# By default the plotting of the first wedge starts from the x-axis and move counterclockwise:

# %% [markdown]
# Note: The size of each wedge is determined by comparing the value with all the other values, by using this formula:
#
#
# The value divided by the sum of all values: x/sum(x)

# %% [markdown]
# # Labels

# %% [markdown]
# Add labels to the pie chart with the label parameter.
#
#
#
# The label parameter must be an array with one label for each wedge:

# %% [markdown]
# A simple pie chart:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# # Start Angle

# %% [markdown]
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
#
#
# The startangle parameter is defined with an angle in degrees, default angle is 0:

# %% [markdown]
# Example
#
#
#
# Start the first wedge at 90 degrees:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# # Explode

# %% [markdown]
# Maybe you want one of the wedges to stand out?
#
#
# The explode parameter allows you to do that.
#
#
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
#
#
# Each value represents how far from the center each wedge is displayed:
#
# Example
#
#
# Pull the "Apples" wedge 0.2 from the center of the pie:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# # Shadow

# %% [markdown]
# Add a shadow to the pie chart by setting the shadows parameter to True:
#
#
# Example
#
#
# Add a shadow:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# # Colors

# %% [markdown]
# You can set the color of each wedge with the colors parameter.
#
#
#
# The colors parameter, if specified, must be an array with one value for each wedge:
#
#
#
# Example
#
#
# Specify a new color for each wedge:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# You can use Hexadecimal color values, any of the 140 supported color names, or one of these shortcuts:
#
#
#
# 'r' - Red
# 'g' - Green
# 'b' - Blue
# 'c' - Cyan
# 'm' - Magenta
# 'y' - Yellow
# 'k' - Black
# 'w' - White

# %% [markdown]
# # Legend

# %% [markdown]
# To add a list of explanation for each wedge, use the legend() function:

# %% [markdown]
# Example
#
#
# Add a legend:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# # Legend With Header

# %% [markdown]
# To add a header to the legend, add the title parameter to the legend function.
#
#
#
# Example
#
#
# Add a legend with a header:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
#  Matplotlib Completed
